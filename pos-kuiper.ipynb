# %%
import scipy.io as scio
import numpy as np 
import math
import pandas as pd
'''
    读入卫星经纬度表示位置矩阵pos_all，含运行方向
    读入卫星cbf表示位置矩阵pos_cbf，不含运行方向
'''
dataFile = "./KUIPER_POSITION.mat"
data = scio.loadmat(dataFile)
pos_all=data['position']
# pos=pos_all[0][i-1] 节点i在所有时刻的位置信息，pos[3][0]表示节点i在0时刻的方向信息

pos_cbf=data['position_cbf']
# pos_cbf[i][0]表示卫星i的所有时刻的位置，pos_cbf[j][0]表示对应卫星在0时刻的位置信息

# %%
for i in pos_all:
    print("var redSphere = viewer.entities.add({name : 'SAT', position: Cesium.Cartesian3.fromDegrees(%f,%f, 610000), ellipsoid : {radii : new Cesium.Cartesian3(70000.0, 70000.0, 70000.0), material : Cesium.Color.BLACK.withAlpha(1),}});"%(i[0][1][0],i[0][0][0]))
    # print(i[0][0][0],i[0][1][0])
# Out:
# var redSphere = viewer.entities.add({name : 'SAT', position: Cesium.Cartesian3.fromDegrees(-100.348162,0.121645, 610000), ellipsoid : {radii : new Cesium.Cartesian3(70000.0, 70000.0, 70000.0), material : Cesium.Color.BLACK.withAlpha(1),}});
# var redSphere = viewer.entities.add({name : 'SAT', position: Cesium.Cartesian3.fromDegrees(-92.881101,6.833847, 610000), ellipsoid : {radii : new Cesium.Cartesian3(70000.0, 70000.0, 70000.0), material : Cesium.Color.BLACK.withAlpha(1),}});
# var redSphere = viewer.entities.add({name : 'SAT', position: Cesium.Cartesian3.fromDegrees(-85.205551,13.425819, 610000), ellipsoid : {radii : new Cesium.Cartesian3(70000.0, 70000.0, 70000.0), material : Cesium.Color.BLACK.withAlpha(1),}});
# var redSphere = viewer.entities.add({name : 'SAT', position: Cesium.Cartesian3.fromDegrees(-77.109466,19.769122, 610000), ellipsoid : {radii : new Cesium.Cartesian3(70000.0, 70000.0, 70000.0), material : Cesium.Color.BLACK.withAlpha(1),}});
# ...

# %%
for i in range(36):
    if i%2==0:
        color="RED"
    else:
        color="BLUE"
    for j in range(0,9):
        id=i*36+j
        id2=id+1
        print("viewer.entities.add({ polyline: { positions: Cesium.Cartesian3.fromDegreesArrayHeights([%f,%f,550000,%f,%f,550000]), width: 3.0, arcType: Cesium.ArcType.GEODESIC, material: new Cesium.PolylineOutlineMaterialProperty({ color: Cesium.Color.%s, outlineWidth: 0, outlineColor: Cesium.Color.BLACK})}});"%(pos_all[id][0][1][0],pos_all[id][0][0][0],pos_all[id2][0][1][0],pos_all[id2][0][0][0],color))
        if i==35:
            id3=j
        else:
            id3=id+36
        print("viewer.entities.add({ polyline: { positions: Cesium.Cartesian3.fromDegreesArrayHeights([%f,%f,550000,%f,%f,550000]), width: 3.0, arcType: Cesium.ArcType.GEODESIC, material: new Cesium.PolylineOutlineMaterialProperty({ color: Cesium.Color.YELLOW, outlineWidth: 0, outlineColor: Cesium.Color.BLACK})}});"%(pos_all[id][0][1][0],pos_all[id][0][0][0],pos_all[id3][0][1][0],pos_all[id3][0][0][0]))
    for j in range(27,36):
        id=i*36+j
        if j==35:
            id2=i*36
        else:   
            id2=id+1
        print("viewer.entities.add({ polyline: { positions: Cesium.Cartesian3.fromDegreesArrayHeights([%f,%f,550000,%f,%f,550000]), width: 3.0, arcType: Cesium.ArcType.GEODESIC, material: new Cesium.PolylineOutlineMaterialProperty({ color: Cesium.Color.%s, outlineWidth: 0, outlineColor: Cesium.Color.BLACK})}});"%(pos_all[id][0][1][0],pos_all[id][0][0][0],pos_all[id2][0][1][0],pos_all[id2][0][0][0],color))
        if i==35:
            id3=j
        else:
            id3=id+36
        print("viewer.entities.add({ polyline: { positions: Cesium.Cartesian3.fromDegreesArrayHeights([%f,%f,550000,%f,%f,550000]), width: 3.0, arcType: Cesium.ArcType.GEODESIC, material: new Cesium.PolylineOutlineMaterialProperty({ color: Cesium.Color.YELLOW, outlineWidth: 0, outlineColor: Cesium.Color.BLACK})}});"%(pos_all[id][0][1][0],pos_all[id][0][0][0],pos_all[id3][0][1][0],pos_all[id3][0][0][0]))
# Out:
# viewer.entities.add({ polyline: { positions: Cesium.Cartesian3.fromDegreesArrayHeights([-100.348162,0.121645,550000,-92.881101,6.833847,550000]), width: 3.0, arcType: Cesium.ArcType.GEODESIC, material: new Cesium.PolylineOutlineMaterialProperty({ color: Cesium.Color.RED, outlineWidth: 0, outlineColor: Cesium.Color.BLACK})}});
# viewer.entities.add({ polyline: { positions: Cesium.Cartesian3.fromDegreesArrayHeights([-100.348162,0.121645,550000,-90.348140,0.119943,550000]), width: 3.0, arcType: Cesium.ArcType.GEODESIC, material: new Cesium.PolylineOutlineMaterialProperty({ color: Cesium.Color.YELLOW, outlineWidth: 0, outlineColor: Cesium.Color.BLACK})}});
# viewer.entities.add({ polyline: { positions: Cesium.Cartesian3.fromDegreesArrayHeights([-92.881101,6.833847,550000,-85.205551,13.425819,550000]), width: 3.0, arcType: Cesium.ArcType.GEODESIC, material: new Cesium.PolylineOutlineMaterialProperty({ color: Cesium.Color.RED, outlineWidth: 0, outlineColor: Cesium.Color.BLACK})}});
# ...
